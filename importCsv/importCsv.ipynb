# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

df = pd.read_csv("test.csv",parse_dates=[0])

# グラフ作成
plt.figure(figsize=(15,4))
plt.plot(df['TIME'],df['INDEX'])

# ロケータで刻み幅を設定
xloc = mpl.dates.MinuteLocator(byminute=range(0,60,1))
plt.gca().xaxis.set_major_locator(xloc)

# 時刻のフォーマットを設定
xfmt = mpl.dates.DateFormatter("%H:%M")
plt.gca().xaxis.set_major_formatter(xfmt)

plt.show()

# %%
df
# Out:
#                  TIME  INDEX
# 0 2018-10-01 23:27:28      1
# 1 2018-10-01 23:42:08      1
# 2 2018-10-01 23:43:15      1
# 3 2018-10-01 23:43:21      1
